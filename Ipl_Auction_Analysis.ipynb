# %% [markdown]
# <a href="https://colab.research.google.com/github/itzaamer/Ipl-Auction-2022-CSK-team-Analysis-/blob/main/Ipl_Auction_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/ipl auctions/IPL_Auction_2022_FullList.csv")

# %%
data.head()
# Out:
#    Set No. Set Name          Player  ... Sold Price          New Franchise   Bid
# 0        1        M     Trent Boult  ...       8 CR       Rajasthan Royals  Sold
# 1        1        M     Pat Cummins  ...    7.25 CR  Kolkata Knight Riders  Sold
# 2        1        M  Shikhar Dhawan  ...    8.25 CR           Punjab Kings  Sold
# 3        1        M    Shreyas Iyer  ...   12.25 CR  Kolkata Knight Riders  Sold
# 4        1        M   Kagiso Rabada  ...    9.25 CR           Punjab Kings  Sold
#
# [5 rows x 17 columns]

# %%
data.shape
# Out:
# (590, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Set No.              590 non-null    int64
#  1   Set Name             590 non-null    object
#  2   Player               590 non-null    object
#  3   Country              590 non-null    object
#  4   State Association    370 non-null    object
#  5   Age                  590 non-null    int64
#  6   Specialism           590 non-null    object
#  7   Batting              590 non-null    object
#  8   Bowling              590 non-null    object
#  9   IPL                  270 non-null    float64
#  10  Previous IPLTeam(s)  265 non-null    object
#  11  2021 Team            165 non-null    object
#  12  C/U/A                590 non-null    object
#  13  Base Price           590 non-null    int64
#  14  Sold Price           187 non-null    object
# ...

# %%
data.describe()
# Out:
#           Set No.         Age         IPL  Base Price
# count  590.000000  590.000000  270.000000  590.000000
# mean    32.130508   26.954237   29.425926   51.872881
# std     17.894093    4.686390   42.904494   53.437927
# min      1.000000   17.000000    0.000000   20.000000
# 25%     17.000000   23.000000    1.000000   20.000000
# 50%     32.000000   27.000000   10.500000   20.000000
# 75%     48.000000   30.000000   38.750000   50.000000
# max     62.000000   43.000000  213.000000  200.000000

# %%
df = data.drop(columns=['State Association'])
df.head()
# Out:
#    Set No. Set Name          Player  ... Sold Price          New Franchise   Bid
# 0        1        M     Trent Boult  ...       8 CR       Rajasthan Royals  Sold
# 1        1        M     Pat Cummins  ...    7.25 CR  Kolkata Knight Riders  Sold
# 2        1        M  Shikhar Dhawan  ...    8.25 CR           Punjab Kings  Sold
# 3        1        M    Shreyas Iyer  ...   12.25 CR  Kolkata Knight Riders  Sold
# 4        1        M   Kagiso Rabada  ...    9.25 CR           Punjab Kings  Sold
#
# [5 rows x 16 columns]

# %%
df['Sold Price'].value_counts()
# Out:
# 20 L       45
# 50 L       14
# 2 CR       11
# 75 L        7
# 1.50 CR     6
#            ..
# 14 CR       1
# 2.4 CR      1
# 2.6 CR      1
# 4.2 CR      1
# 90 L        1
# Name: Sold Price, Length: 65, dtype: int64

# %%
df[df['Age']==df['Age'].min()]
# Out:
#     Set No. Set Name      Player  ... Sold Price   New Franchise   Bid
# 72       11     USP1  Noor Ahmad  ...       30 L  Gujarat Titans  Sold
#
# [1 rows x 16 columns]

# %%
df[df['Age']==df['Age'].max()]
# Out:
#      Set No. Set Name       Player  ... Sold Price  New Franchise     Bid
# 193        6      SP1  Imran Tahir  ...        NaN            NaN  UnSold
#
# [1 rows x 16 columns]

# %%
df["New Franchise"].value_counts()
# Out:
# Kolkata Knight Riders          20
# Punjab Kings                   20
# Sunrisers Hyderabad            20
# Rajasthan Royals               19
# Royal Challengers Bangalore    19
# Mumbai Indians                 19
# Delhi Capitals                 18
# Gujarat Titans                 17
# Chennai Super Kings            17
# Lucknow Super Giants           16
# Luknow Super Giants             1
# Gujarat Titan                   1
# Name: New Franchise, dtype: int64

# %%
df.isnull().sum()
# Out:
# Set No.                  0
# Set Name                 0
# Player                   0
# Country                  0
# Age                      0
# Specialism               0
# Batting                  0
# Bowling                  0
# IPL                    320
# Previous IPLTeam(s)    325
# 2021 Team              425
# C/U/A                    0
# Base Price               0
# Sold Price             403
# New Franchise          403
# Bid                      0
# dtype: int64

# %% [markdown]
# <h3>Observations:
#
# - As we seen above there are number of Nan value is present inside the dataset that because of the some player have auction first time or some player won't buy.

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Bid',data=df)

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we get there more than 50 % of player are goes unsold as compare to the sold.
# - There are around 200 player are goes sold and 400 player is goes unsold.

# %% [markdown]
# <h2>Observations of Csk auction 2022:

# %%
df[df["New Franchise"]=='Chennai Super Kings']
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 15         2      BA1  ...  Chennai Super Kings  Sold
# 16         3      AL1  ...  Chennai Super Kings  Sold
# 29         4      WK1  ...  Chennai Super Kings  Sold
# 33         5      FA1  ...  Chennai Super Kings  Sold
# 67        10     UFA1  ...  Chennai Super Kings  Sold
# 80        13      AL2  ...  Chennai Super Kings  Sold
# 83        13      AL2  ...  Chennai Super Kings  Sold
# 98        15      SP2  ...  Chennai Super Kings  Sold
# 102       17     UAL2  ...  Chennai Super Kings  Sold
# 112       18     UFA2  ...  Chennai Super Kings  Sold
# 114       19      BA3  ...  Chennai Super Kings  Sold
# 122       20      AL3  ...  Chennai Super Kings  Sold
# 125       20      AL3  ...  Chennai Super Kings  Sold
# 135       22      FA3  ...  Chennai Super Kings  Sold
# 136       24     UBA3  ...  Chennai Super Kings  Sold
# 146       27     UFA3  ...  Chennai Super Kings  Sold
# ...

# %%
df[(df['New Franchise'] == 'Chennai Super Kings') & (df['Age']>35)]
# Out:
#     Set No. Set Name         Player  ... Sold Price        New Franchise   Bid
# 15        2      BA1  Robin Uthappa  ...       2 CR  Chennai Super Kings  Sold
# 16        3      AL1   Dwayne Bravo  ...     4.4 CR  Chennai Super Kings  Sold
# 29        4      WK1  Ambati Rayudu  ...    6.75 CR  Chennai Super Kings  Sold
#
# [3 rows x 16 columns]

# %%
df[(df['New Franchise'] == 'Chennai Super Kings') & (df['Age']<20)]
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 102       17     UAL2  ...  Chennai Super Kings  Sold
#
# [1 rows x 16 columns]

# %%
df[(df['New Franchise']=="Chennai Super Kings")& (df['Country']=='West Indies')]
# Out:
#     Set No. Set Name        Player  ... Sold Price        New Franchise   Bid
# 16        3      AL1  Dwayne Bravo  ...     4.4 CR  Chennai Super Kings  Sold
#
# [1 rows x 16 columns]

# %%
df[(df['New Franchise']=="Chennai Super Kings")& (df['C/U/A']=='Capped')]
# Out:
#      Set No. Set Name              Player  ... Sold Price        New Franchise   Bid
# 15         2      BA1       Robin Uthappa  ...       2 CR  Chennai Super Kings  Sold
# 16         3      AL1        Dwayne Bravo  ...     4.4 CR  Chennai Super Kings  Sold
# 29         4      WK1       Ambati Rayudu  ...    6.75 CR  Chennai Super Kings  Sold
# 33         5      FA1       Deepak Chahar  ...      14 CR  Chennai Super Kings  Sold
# 80        13      AL2         Shivam Dube  ...       4 CR  Chennai Super Kings  Sold
# 83        13      AL2        Chris Jordan  ...    3.60 CR  Chennai Super Kings  Sold
# 98        15      SP2  Maheesh Theekshana  ...       70 L  Chennai Super Kings  Sold
# 114       19      BA3        Devon Conway  ...       1 CR  Chennai Super Kings  Sold
# 122       20      AL3    Dwaine Pretorius  ...       50 L  Chennai Super Kings  Sold
# 125       20      AL3    Mitchell Santner  ...    1.90 CR  Chennai Super Kings  Sold
# ...

# %%
df[(df['New Franchise']=='Chennai Super Kings') & (df["C/U/A"]=="Uncapped")]
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 67        10     UFA1  ...  Chennai Super Kings  Sold
# 102       17     UAL2  ...  Chennai Super Kings  Sold
# 112       18     UFA2  ...  Chennai Super Kings  Sold
# 136       24     UBA3  ...  Chennai Super Kings  Sold
# 146       27     UFA3  ...  Chennai Super Kings  Sold
# 152       28     USP2  ...  Chennai Super Kings  Sold
#
# [6 rows x 16 columns]

# %%
df[(df['New Franchise']=='Chennai Super Kings') & (df["Sold Price"]=="20 L")]
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 67        10     UFA1  ...  Chennai Super Kings  Sold
# 112       18     UFA2  ...  Chennai Super Kings  Sold
# 136       24     UBA3  ...  Chennai Super Kings  Sold
# 146       27     UFA3  ...  Chennai Super Kings  Sold
#
# [4 rows x 16 columns]

# %%
df[(df['New Franchise']=='Chennai Super Kings') & (df["Sold Price"]>"2 CR")]
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 16         3      AL1  ...  Chennai Super Kings  Sold
# 29         4      WK1  ...  Chennai Super Kings  Sold
# 67        10     UFA1  ...  Chennai Super Kings  Sold
# 80        13      AL2  ...  Chennai Super Kings  Sold
# 83        13      AL2  ...  Chennai Super Kings  Sold
# 98        15      SP2  ...  Chennai Super Kings  Sold
# 112       18     UFA2  ...  Chennai Super Kings  Sold
# 122       20      AL3  ...  Chennai Super Kings  Sold
# 136       24     UBA3  ...  Chennai Super Kings  Sold
# 146       27     UFA3  ...  Chennai Super Kings  Sold
#
# [10 rows x 16 columns]

# %%
df[['New Franchise','Player','Age']][df['Sold Price']=='20 L']
# Out:
#                    New Franchise               Player  Age
# 46           Sunrisers Hyderabad          Priyam Garg   21
# 47                Delhi Capitals        Ashwin Hebbar   26
# 49                Mumbai Indians     Anmolpreet Singh   24
# 54                Delhi Capitals        Sarfaraz Khan   24
# 63                  Punjab Kings        Jitesh Sharma   28
# 66   Royal Challengers Bangalore           Akash Deep   25
# 67           Chennai Super Kings     Tushar Deshpande   26
# 75           Sunrisers Hyderabad   Jagadeesha Suchith   28
# 100         Lucknow Super Giants          Manan Vohra   28
# 104               Gujarat Titans     Darshan Nalkande   23
# 105               Delhi Capitals         Vicky Ostwal   19
# 106               Delhi Capitals          Ripal Patel   26
# 107        Kolkata Knight Riders           Anukul Roy   23
# 111             Rajasthan Royals          Kuldeep Sen   25
# 112          Chennai Super Kings      Simarjeet Singh   24
# ...

# %%
len(df[['New Franchise','Player','Age']][df['Sold Price']=='20 L'])
# Out:
# 45

# %%
df[['New Franchise','Player','Age']][df['Sold Price']<'10 CR']
# Out:
#                    New Franchise                  Player  Age
# 30                Gujarat Titans         Wriddhiman Saha   37
# 57                Delhi Capitals       Kamlesh Nagarkoti   22
# 73                Mumbai Indians          Murugan Ashwin   31
# 77         Kolkata Knight Riders          Ajinkya Rahane   33
# 78                Delhi Capitals           Mandeep Singh   30
# 79                Gujarat Titans          Dominic Drakes   24
# 85              Rajasthan Royals           James Neesham   31
# 86                Gujarat Titans           Vijay Shankar   31
# 88                Gujarat Titans            Jayant Yadav   32
# 94                Mumbai Indians          Jaydev Unadkat   30
# 102          Chennai Super Kings  Rajvardhan Hangargekar   19
# 114          Chennai Super Kings            Devon Conway   30
# 115        Kolkata Knight Riders              Alex Hales   33
# 117             Rajasthan Royals              Karun Nair   30
# ...

# %%
sns.scatterplot(x=df['Age'],y=df['Age'].value_counts(),hue=(df['New Franchise']=='Chennai Super kings'),data=df)

# %%
df[(df['New Franchise']=='Chennai Super Kings')&(df['2021 Team']=="CSK")]
# Out:
#      Set No. Set Name            Player  ... Sold Price        New Franchise   Bid
# 15         2      BA1     Robin Uthappa  ...       2 CR  Chennai Super Kings  Sold
# 16         3      AL1      Dwayne Bravo  ...     4.4 CR  Chennai Super Kings  Sold
# 29         4      WK1     Ambati Rayudu  ...    6.75 CR  Chennai Super Kings  Sold
# 33         5      FA1     Deepak Chahar  ...      14 CR  Chennai Super Kings  Sold
# 125       20      AL3  Mitchell Santner  ...    1.90 CR  Chennai Super Kings  Sold
#
# [5 rows x 16 columns]

# %%
df[(df['New Franchise']=='Chennai Super Kings')&(df['2021 Team']!="CSK")]
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 67        10     UFA1  ...  Chennai Super Kings  Sold
# 80        13      AL2  ...  Chennai Super Kings  Sold
# 83        13      AL2  ...  Chennai Super Kings  Sold
# 98        15      SP2  ...  Chennai Super Kings  Sold
# 102       17     UAL2  ...  Chennai Super Kings  Sold
# 112       18     UFA2  ...  Chennai Super Kings  Sold
# 114       19      BA3  ...  Chennai Super Kings  Sold
# 122       20      AL3  ...  Chennai Super Kings  Sold
# 135       22      FA3  ...  Chennai Super Kings  Sold
# 136       24     UBA3  ...  Chennai Super Kings  Sold
# 146       27     UFA3  ...  Chennai Super Kings  Sold
# 152       28     USP2  ...  Chennai Super Kings  Sold
#
# [12 rows x 16 columns]

# %%
df[(df['New Franchise']=='Chennai Super Kings')&(df['Base Price']==20)]
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 67        10     UFA1  ...  Chennai Super Kings  Sold
# 112       18     UFA2  ...  Chennai Super Kings  Sold
# 136       24     UBA3  ...  Chennai Super Kings  Sold
# 146       27     UFA3  ...  Chennai Super Kings  Sold
# 152       28     USP2  ...  Chennai Super Kings  Sold
#
# [5 rows x 16 columns]

# %%
df[(df['New Franchise']=='Chennai Super Kings')&(df['Base Price']>20)]
# Out:
#      Set No. Set Name  ...        New Franchise   Bid
# 15         2      BA1  ...  Chennai Super Kings  Sold
# 16         3      AL1  ...  Chennai Super Kings  Sold
# 29         4      WK1  ...  Chennai Super Kings  Sold
# 33         5      FA1  ...  Chennai Super Kings  Sold
# 80        13      AL2  ...  Chennai Super Kings  Sold
# 83        13      AL2  ...  Chennai Super Kings  Sold
# 98        15      SP2  ...  Chennai Super Kings  Sold
# 102       17     UAL2  ...  Chennai Super Kings  Sold
# 114       19      BA3  ...  Chennai Super Kings  Sold
# 122       20      AL3  ...  Chennai Super Kings  Sold
# 125       20      AL3  ...  Chennai Super Kings  Sold
# 135       22      FA3  ...  Chennai Super Kings  Sold
#
# [12 rows x 16 columns]

# %%
df[(df['2021 Team']=='CSK')]
# Out:
#      Set No. Set Name  ...                New Franchise     Bid
# 8          1        M  ...  Royal Challengers Bangalore    Sold
# 15         2      BA1  ...          Chennai Super Kings    Sold
# 16         3      AL1  ...          Chennai Super Kings    Sold
# 29         4      WK1  ...          Chennai Super Kings    Sold
# 33         5      FA1  ...          Chennai Super Kings    Sold
# 35         5      FA1  ...  Royal Challengers Bangalore    Sold
# 39         5      FA1  ...               Delhi Capitals    Sold
# 79        13      AL2  ...               Gujarat Titans    Sold
# 81        13      AL2  ...         Lucknow Super Giants    Sold
# 97        15      SP2  ...  Royal Challengers Bangalore    Sold
# 125       20      AL3  ...          Chennai Super Kings    Sold
# 129       22      FA3  ...  Royal Challengers Bangalore    Sold
# 187        2      BA1  ...                          NaN  UnSold
# 193        6      SP1  ...                          NaN  UnSold
# ...

# %%
df[(df['New Franchise']=='Chennai Super Kings')&(df['2021 Team']=="MI")]
# Out:
#      Set No. Set Name           Player  ... Sold Price        New Franchise   Bid
# 112       18     UFA2  Simarjeet Singh  ...       20 L  Chennai Super Kings  Sold
# 135       22      FA3       Adam Milne  ...     1.90 L  Chennai Super Kings  Sold
#
# [2 rows x 16 columns]

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on player Age')
sns.countplot(x=df['Age'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we get we won't buy any player who age is less than 19 in this 2022 auction.
# - We buy around 10 player who's age is more than 30 in this auction.
# - Maximum age of the player is 38 and minimum is 19.

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on player 2021 Team')
sns.countplot(x=df['2021 Team'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we get we buy 5 player who played in our 2021 team.
# - in these auction we buy MI player who played in MI 2021 team.
# - One from RR and one from pbks.

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on player Specialism')
sns.countplot(x=df['Specialism'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we get we buy 1 wicket keeper because we have MSD we don't require it .
# - we buy 7 bowler in these auction and 3 batmans .
# - we buy 6 all rounder in these auctions.

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on Capped or uncapped player')
sns.countplot(x=df['C/U/A'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we go for the capped player in these auction .
# - there are more than 10 player we buy who is capped ,and we buy 6 player who's uncappped.

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on sold price')
sns.countplot(x=df['Sold Price'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we get more player at 20 lac
# - maximum buying price is 14 cr in these auction  .

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on Base Price')
sns.countplot(x=df['Base Price'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on Bowling player')
sns.countplot(x=df['Bowling'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we go fror the faster as compare to the spinner in these auction.
# - Around 10 faster boiwler we buy in these auction.

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on Batting player')
sns.countplot(x=df['Batting'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we go for the RHB player in these auction .
# - there are more than 12 player  we buy who can played RHB.
# - we buy 4 player we can played LHB.

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on Country player')
sns.countplot(x=df['Country'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we go the indian player ,in these auction around 10 indian player e buy.
# - 1 from wi and eng sri and south africa .
# - we buy 2 player from the nz.

# %%
plt.figure(figsize=(15,5))
plt.title('Csk Team Analysis on Set no.1 buying player')
sns.countplot(x=df['Set No.'][df['New Franchise']=='Chennai Super Kings'],data=df[df['New Franchise']=='Chennai Super Kings'])

# %% [markdown]
# <h3>Observations:
#
# - As we seen above in the set no. 13 and 20  we buy 2 player .
# - in each set no we buy 1 player .
# - in set 1 we won't buy any player.

# %%
plt.figure(figsize=(16,8))
plt.title('Csk Buying player')
plt.plot(df['Base Price'][df['New Franchise']=='Chennai Super Kings'],df['Sold Price'][df['New Franchise']=='Chennai Super Kings'])
plt.xlabel('Base Price', fontsize=18)
plt.ylabel('Sold Price ', fontsize=18)
plt.show()

# %% [markdown]
# <h3>Observations:
#
# - As we seen above we get that dataset is not ijn proper condition in term of sold price  that's why this type of plot is occur.
# - if we make the dataset in lac and crore these will give us best result.
